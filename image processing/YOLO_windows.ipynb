# %% [markdown]
# windows 개발환경으로 darknet 실행

# %%
import cv2

print(cv2.__version__)
# Out:
# 4.5.4

# %% [markdown]
# # cfg 경로
# C:\Users\KSY\Desktop\YOLOtest\darknet-master\cfg\yolov4-obj.cfg
#
# # names 경로
# C:\Users\KSY\Desktop\YOLOtest\darknet-master\build\darknet\x64\data\obj.names
# # data 경로
# C:\Users\KSY\Desktop\YOLOtest\darknet-master\build\darknet\x64\data\obj.data
# # train 경로
# C:\Users\KSY\Desktop\YOLOtest\darknet-master\build\darknet\x64\data\train.txt
# # test 경로
# C:\Users\KSY\Desktop\YOLOtest\darknet-master\build\darknet\x64\data\test.txt
# # 이미지 테스트 경로
# C:\Users\KSY\Desktop\YOLOtest\darknet-master\build\darknet\x64\data\obj\gcooter_100001.jpg
# # backup 경로
# C:\Users\KSY\Desktop\YOLOtest\darknet-master\build\darknet\x64\backup
#
# # 가중치 파일
# C:\Users\KSY\Desktop\YOLOtest\darknet-master\build\darknet\x64\yolov4-obj_final.weights

# %%
# %cd C:\Users\KSY\Desktop\YOLOtest\darknet-master
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile # opencv만 1로 바꿔서 on으로 설정

#아래 코드는 GPU가 없기에 옵션을 건드려주지 않음
#!sed -i 's/GPU=0/GPU=1/' Makefile
#!sed -i 's/CUDNN=0/CUDNN=1/' Makefile
#!sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile

# %% [markdown]
# 아래 링크를 참고하여 GPU없이 darknet을 실행할 수 있도록 exe파일을 만들어 줌
# https://reyrei.tistory.com/19

# %%
# !make # make 파일 생성
# Out:
# 'make'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# 이미지를 보여주는 함수 정의
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  #%matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# %%
#학습한 가중치 test

# %cd C:/Users/KSY/Desktop/YOLOtest/darknet-master

#학습한 가중치(weight) 뒤에 -thresh 소숫점은 정확도가 몇퍼 이상이면 검출되도록 해주는 옵션
# !darknet_no_gpu.exe detector test data/obj.data C:/Users/KSY/Desktop/YOLOtest/darknet-master/cfg/yolov4-obj.cfg yolov4-obj_final.weights -thresh 0.5 data/obj/gcooter_100001.jpg -ext_output

# %%
imShow('predictions.jpg')
